# %% [markdown]
# <a href="https://colab.research.google.com/github/flarissams-beep/Estadistica2025B/blob/main/Problemario_Estad%C3%ADstica_Inferencial_II.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Unidad 1. Regresión lineal simple y correlación

# %% [markdown]
# ## Medidas de dispersión
# Suma de los cuadrados de las desviaciones de los valores de $X$ con respecto a su media:
# $$ S_{xx} = \sum_{i=1}^{n} (X_i - \bar{X})^2 $$
# Suma de los productos de las desviaciones de los valores de $X$ y $Y$ con respecto a sus medias:
# $$S_{xy} = \sum_{i=1}^{n} (X_i - \bar{X})(Y_i - \bar{Y})$$
# Suma de los cuadrados de las desviaciones de los valores de $Y$ con respecto a su media:
# $$ S_{xx} = \sum_{i=1}^{n} (Y_i - \bar{Y})^2 $$

# %% [markdown]
# ## Coeficiente de correlación y de determinación
# Coeficiente de correlación de Pearson:
# $$ r = \frac{S_{xy}}{\sqrt{S_{xx} \cdot S_{yy}}} $$
# Coeficiente de determinación:
# $$ r^2 $$

# %% [markdown]
# ## Recta de regresión ajustada
# La regresión lineal ajustada se representa mediante estadísticos:
# $$ \hat{Y} = b_0 + b_1 X $$
# donde $\hat{Y}$ representa el valor de $Y$ obtenido mediante la recta de regresión ajustada (no la verdadera $Y$). Los estadísticos $b_0$ y $b_1$ se calculan de la siguiente manera:
#
# $$b_1 = \frac{S_{xy}}{S_{xx}}$$
#
# $$ b_0 = \bar{Y} - b_1 \bar{X} $$

# %% [markdown]
# ## Cálculo de residuales
# Residuales:
# $$e_i = Y_i - \hat{Y}_i$$

# %% [markdown]
# ## Sumas de cuadrados SS (Sum of Squares)
# Suma de los Cuadrados de los Errores:
# $$ SSE = \sum_{i=1}^{n} (Y_i - \hat{Y}_i)^2 = \sum_{i=1}^n e_i^2$$
# Suma total de cuadrados:
# $$SST = \sum_{i=1}^{n} (Y_i - \bar{Y})^2$$
# Suma de cuadrados de regresión:
# $$SSR = \sum_{i=1}^{n} (\hat{Y_i} - \bar{Y})^2$$
# - SST: Mide la variabilidad total de los datos observados.
# - SSR: Mide la variabilidad de los datos que el modelo de regresión explica.
# - SSE: Mide la variabilidad no explicada por el modelo (es decir, los residuos).

# %% [markdown]
# ## Intervalo de confianza
# Estadístico de prueba _t_:
# $$t = \frac{b_1}{SE(b_1)}$$
# Error estándar de $b_1$:
# $$SE(b_1) = \frac{\sqrt{SSE / (n-2)}}   {\sqrt{S_{xx}} }$$
# o
# $$SE(b_1) = \frac{\sqrt{\sum_{i=1}^{n} (Y_i - \hat{Y}_i)^2  / (n-2)}}   {\sqrt{S_{xx}} }$$
#
# Intervalo de confianza para $b_1$:
# $$b_1 - t_{\alpha/2} \cdot SE(b_1) \lt \beta_1 \lt b_1 + t_{\alpha/2} \cdot SE(b_1)$$
# donde $n$ representa la cantidad de pares de datos.

# %% [markdown]
# ## Comprobación de supuestos
# Comprobar suposiciones:
# - Test de shapiro a los residuales $e_i$: Para comprobar si la distribución es normal sobre la recta.
# - Grafico $X$ vs $Y$: Para observar si los datos soportan la suposición de linealidad.
# - Gráfico de residuales: Para observar si los datos soportan la suposición de linealidad, complementario al coeficiente de correlación
# - Test de Breusch-Pagan: Para detectar heteroscedasticidad en regresion lineal

# %% [markdown]
# Test de Shapiro:<br>
# `from scipy.stats import shapiro`<br>
# Después, se obtiene el valor-p:<br>
# `_, valor_p_sh = shapiro(data)`<br>
# - $H_0$: Los datos siguen una distribución normal
# - $H_1$: Los datos no siguen una distribución normal

# %% [markdown]
# Test de Breusch-Pagan:<br>
# `from statsmodels.stats.api import het_breuschpagan`<br>
# Después, se obtiene el valor-p:<br>
# `_, valor_p_bp, _, _ = het_breuschpagan(residuales, X)`
# - $H_0$: Hay homoscedasticidad
# - $H_1$: Hay heteroscedasticidad

# %% [markdown]
# ## ANOVA en regresión lineal
#
# | Fuente de variación | Suma de cuadrados (SS) | Grados de libertad (df) | Promedio de los cuadrados (MS) | Estadístico F |
# |---------------------|------------------------|--------------------------|--------------------------------|---------------|
# | Regresión  | $ SSR$ | $p$ | $MSR = \frac{SSR}{p}$ | $F = \frac{MSR}{MSE}$|
# | Error | $SSE$| $n - p - 1 $| $MSE = \frac{SSE}{n - p - 1} $|     |
# | Total | $SST $| $n - 1$|             |        |
#
# donde $p$ es el número de parámetros para la recta de regresión ajustada (en la regresión simple $p=1$). Las hipótesis son:
# $$H_0: \beta_1 = 0$$
# $$H_1: \beta_1 \ne 0 $$

# %% [markdown]
# ## Problemario de la Unidad 1

# %% [markdown]
# ### Problema 1
# Un profesor intenta mostrar a sus estudiantes la importancia de los exámenes cortos, aun cuando el 90% de la calificación final esté determinada por los exámenes parciales. Él cree que cuanto más altas sean las calificaciones de los exámenes cortos, más alta será la calificación final. Seleccionó una muestra aleatoria de 15 estudiantes de su clase con los siguientes datos:
#
# | Promedio de exámenes cortos | Promedio final |
# |--------------|--------------|
# | 59 | 64 |
# | 92 | 84 |
# | 72 | 77 |
# | 90 | 80 |
# | 95 | 77 |
# | 87 | 81 |
# | 89 | 80 |
# | 77 | 84 |
# | 76 | 80 |
# | 65 | 69 |
# | 97 | 83 |
# | 42 | 40 |
# | 94 | 78 |
# | 62 | 65 |
# | 91 | 90 |
#
#
#
# 1.   Establesca una variable dependiente ($Y$) y una variable independiente ($X$).
# 2.   Realice un diagrama de dispersión para estos datos.
# 3. ¿Los datos soportan la suposición de linealidad?
# 4. Calcule el coeficiente de correlación e interprete el resultado.
# 5. Calcule el coeficiente de determinación e interprete el resultado.
# 6. Obtenga la recta de regresión ajustada y grafíquelo sobre el gráfico de dispersión.
# 7. Obtenga un intervalo de confianza del 95% para la pendiente de la recta de regresión ajustada ($b_1$)
# 8. Calcule los residuales y trace un nuevo gráfico de dispersión. Comente, ¿Parece que se verifican los supuestos?
# 9. Realice la prueba de Shapiro para los residuales y comente el resultado.
# 10. Realice la prueba de Brausch-Pagan para los residuales y comente el resultado.
# 11. Tres estudiantes sacaron 70, 75 y 84 de calificación. Según la recta de regresión ajustada, ¿cuáles son los resultados esperados para estos tres alumnos?
# 12. Realice una tabla ANOVA e interprete el resultado.

# %%
import pandas as pd
df = pd.DataFrame({
"examenes_cortos": [59, 92, 72, 90, 95, 87, 89, 77, 76, 65, 97, 42, 94, 62, 91],
"promedio_final": [64, 84, 77, 80, 77, 81, 80, 84, 80, 69, 83, 40, 78, 65, 90]
})


# inciso 1) Establesca una variable dependiente ( Y ) y una variable independiente ( X ).
X = df["examenes_cortos"]
Y = df["promedio_final"]


# inciso 2) Realice un diagrama de dispersión para estos datos.

plt.figure (figsize = (16,8), dpi = 100) # crea una gráfica
plt.scatter(X,Y, label = "calificación", color = "blue", s = 30)
plt.xlabel("examenes cortos", fontsize = 20)  # el label nombra el eje (x)
plt.ylabel("promedio final", fontsize = 20)   # el label nombra el eje (y)
plt.title("Gráfico de dispersión", fontsize = 20)
plt.gca() .spines [["top","right"]].set_visible (False) # borra la línea de arriba y la derecha

plt.grid() # genera líneas entre cada número

plt.legend() # para que aparezcan los (label) (llama las etiquetas que usamos)
 # se cierra el gráfico con plt.show()

# inciso 3) ¿Los datos soportan la suposición de linealidad?
            # Sí soporta la suposición de linealidad


# inciso 4) Calcule el coeficiente de correlación e interprete el resultado.
                                        #forma difícil {
Sxx = sum((X - X.mean())**2)
Sxy = sum((X - X.mean())*(Y - Y.mean()))
Syy = sum((Y - Y.mean())**2)

print (Sxx)
print (Sxy)
print (Syy)

from math import sqrt
r = Sxy / sqrt (Sxx * Sxy)
print ("coeficiente de correlación= ", round (r,4) )
                                        #forma difícil }
print ("Coeficiente de correlación (forma fácil)", df.corr())
                                        #(corr) correlación
from scipy.stats import pearsonr
print ("Coeficiente de correlación= ", pearsonr(X,Y)) #calcula el coeficiente de correlación y el valor-p



# inciso 5) Calcule el coeficiente de determinación e interprete el resultado.
r2 = r**2
print ("Coeficiente de determinación: ", r2) #para calcular el coeficiente de determinación
# por lo que el coeficiente de determinación depende de la cantidad
#r = pearsonr (x,y)
print ("Coeficiente de determinación: ", round(r2, 4)) # Alt + teclado de :_ y - = \
                                                      #Alt + teclado de :} y ] = ~ (significa: pertenece a...)


# inciso 6) Obtenga la recta de regresión ajustada y grafíquelo sobre el gráfico de dispersión.

import statsmodels.api as sm
X_constante=sm.add_constant(X) #Tabla de examenes cortos
modelo = sm.OLS(Y,X_constante).fit() #Sólo asignamos
modelo.params #queremos ver los modelos de parámetros (da una gráfica) Y:promedio final
#si lo que remos ver con print (print ("parámetros: ", modelo.params))
Yc = modelo.predict (X_constante)
plt.plot (X, Yc, color = "black", linestyle = "--",
          linewidth = 2, alpha = 0.5)

#forma difícil(no hacer caso){
from sklearn.metrics import r2_score
r2 = r2_score (Y, Yc)
#forma difícil}


plt.show()

# inciso 7) Obtenga un intervalo de confianza del 95% para la pendiente de la recta de regresión ajustada ( b1 )
intervalo_de_confianza = modelo.conf_int (alpha = 0.05)
intervalo_de_confianza
print ("intervalos de confianza: ", intervalo_de_confianza)


# inciso 8) Calcule los residuales y trace un nuevo gráfico de dispersión. Comente, ¿Parece que se verifican los supuestos?
import matplotlib.pyplot as plt
residuales = modelo.resid
plt.figure (figsize = (16,8), dpi = 100) # crea una gráfica
plt.scatter(X,residuales, label = "residuales", color = "blue", s = 30)
plt.xlabel("Examenes Cortos", fontsize = 20)  # el label nombra el eje (x)
plt.ylabel("Residuales", fontsize = 20)   # el label nombra el eje (y)
plt.title("Gráfico de Residuales", fontsize = 20)
plt.gca() .spines [["top","right"]].set_visible (False) # borra la línea de arriba y la derecha
plt.grid()
plt.legend()
plt.axhline(y = 0, color = "F54927", linestyle = "--") #crea una línea punteada en el gráfico
plt.show()


# inciso 9) Realice la prueba de Shapiro para los residuales y comente el resultado.
from scipy.stats import shapiro
estadistico_shapiro, valor_p_shapiro = shapiro (residuales) #asigna el valor_p
print("valor_p (shapiro) = ", valor_p_shapiro) #imprime el valor_p de shapiro
#indica la normalidad el dato estadístico aunque en la gráfica no se vea así a simple vista
#por el nivel de significancia, si es mayor a 0.05 hay normalidad, en base a las hipótesis de Word


# inciso 10) Realice la prueba de Brausch-Pagan para los residuales y comente el resultado.
from statsmodels.stats.api import het_breuschpagan
_, valor_p_bp, _, _ = het_breuschpagan(residuales, X_constante)
print(f'valor_p de Breusch-Pagan: {valor_p_bp: 0.4f}\n')
#indica que si hay homocedasticidad por el valor_p


# inciso 11) Tres estudiantes sacaron 70, 75 y 84 de calificación. Según la recta de regresión ajustada, ¿cuáles son los resultados esperados para estos tres alumnos?
modelo.params
#f(x) = 24.52 + 0.64X
#f(70) = 24.52 + 0.64(70) = 69.32

print("x = 70, ",modelo.predict([1,70]))
print("x = 75, ",modelo.predict([1,75]))
print("x = 84, ",modelo.predict([1,84]))


# inciso 12) Realice una tabla ANOVA e interprete el resultado.
from statsmodels.formula.api import ols
modelo_lineal = ols("promedio_final ~ examenes_cortos", data = df).fit()
tabla_anova =  sm.stats.anova_lm(modelo_lineal)
tabla_anova

# lo que aparece como sugerencia                   {import statsmodels.api as sm
# anova = sm.OLS(Y,X_constante).fit().summary()
# print(anova))                                    }
# Out:
# 3718.4
# 2391.6
# 2057.7333333333336
# coeficiente de correlación=  0.802
# Coeficiente de correlación (forma fácil)                  examenes_cortos  promedio_final
# examenes_cortos         1.000000        0.864601
# promedio_final          0.864601        1.000000
# Coeficiente de correlación=  PearsonRResult(statistic=np.float64(0.8646014213752983), pvalue=np.float64(3.1971844162345565e-05))
# Coeficiente de determinación:  0.6431798623063685
# Coeficiente de determinación:  0.6432
# intervalos de confianza:                          0          1
# const            6.441997  42.611646
# examenes_cortos  0.419219   0.867141
# valor_p (shapiro) =  0.901827735700704
# valor_p de Breusch-Pagan:  0.2289
#
# x = 70,  [69.54941193]
# x = 75,  [72.76531124]
# x = 84,  [78.55393001]
#                    df       sum_sq      mean_sq          F    PR(>F)
# examenes_cortos   1.0  1538.228959  1538.228959  38.492412  0.000032
# Residual         13.0   519.504375    39.961875        NaN       NaN

# %% [markdown]
# ### Problema 2
# William Hawkins, vicepresidente de personal de la International Motors, trabaja en la relación entre el salario de un trabajador y el porcentaje de ausentismo. Hawkins dividió el intervalo de salarios de International en 12 grados o niveles (1 es el menor grado, 12 el más alto) y después muestreó aleatoriamente a un grupo de trabajadores. Determinó el grado de salario de cada trabajador y el número de días que ese empleado había faltado en los últimos 3 años.
#
# | Categoría de salario | 11 | 10 | 8  | 5  | 9  | 7  | 3  |
# |----------------------|----|----|----|----|----|----|----|
# | Ausencias           | 18 | 17 | 29 | 36 | 11 | 28 | 35 |
#
# | Categoría de salario | 11 | 8  | 7  | 2  | 9  | 8  | 3  |
# |----------------------|----|----|----|----|----|----|----|
# | Ausencias           | 14 | 20 | 32 | 39 | 16 | 31 | 40 |
#
# 1.   Establesca una variable dependiente ($Y$) y una variable independiente ($X$).
# 2.   Realice un diagrama de dispersión para estos datos.
# 3. ¿Los datos soportan la suposición de linealidad?
# 4. Calcule el coeficiente de correlación e interprete el resultado.
# 5. Calcule el coeficiente de determinación e interprete el resultado.
# 6. Obtenga la recta de regresión ajustada y grafíquelo sobre el gráfico de dispersión.
# 7. Obtenga un intervalo de confianza del 95% para la pendiente de la recta de regresión ajustada ($b_1$)
# 8. Calcule los residuales y trace un nuevo gráfico de dispersión. Comente, ¿Parece que se verifican los supuestos?
# 9. Realice la prueba de Shapiro para los residuales y comente el resultado.
# 10. Realice la prueba de Brausch-Pagan para los residuales y comente el resultado.
# 11. Utiliza la recta de regresión para interpolar dos valores y extrapolar uno. Comenta estos resultados.
# 12. Realice una tabla ANOVA e interprete el resultado.

# %%
import pandas as pd
df = pd.DataFrame({
"ausencias": [18,17,29,36,11,28,35,14,20,32,39,16,31,40],
"categoría_salario": [11,10,8,5,9,7,3,11,8,7,2,9,8,3]
})


# inciso 1) Establesca una variable dependiente ( Y ) y una variable independiente ( X ).
# Salario ~ ausencia (y ~ x)
x = df["ausencias"]
y = df["categoría_salario"]


# inciso 2) Realice un diagrama de dispersión para estos datos.
import matplotlib.pyplot as plt
plt.figure (figsize = (16,8), dpi = 100) # crea una gráfica
plt.scatter(x,y, label = "Asistencias", color = "pink", s = 30)
plt.xlabel("Ausencias", fontsize = 20)  # el label nombra el eje (x)
plt.ylabel("Categoría de Salario", fontsize = 20)   # el label nombra el eje (y)
plt.title("Gráfico de dispersión", fontsize = 20)
plt.gca() .spines [["top","right"]].set_visible (False) # borra la línea de arriba y la derecha
plt.grid() # genera líneas entre cada número
plt.legend() # para que aparezcan los (label) (llama las etiquetas que usamos)
 # se cierra el gráfico con plt.show()



# inciso 3) ¿Los datos soportan la suposición de linealidad?
            # Sí soporta la suposición de linealidad por el momento en r


# inciso 4) Calcule el coeficiente de correlación e interprete el resultado.
                                        #forma difícil {
Sxx = sum((x - x.mean())**2)
Sxy = sum((x - x.mean())*(y - y.mean()))
Syy = sum((y - y.mean())**2)

print (Sxx)
print (Sxy)
print (Syy)

from math import sqrt
r = Sxy / sqrt (Sxx * Syy)
print ("coeficiente de correlación= ", round (r,4) )
                                        #forma difícil }
print ("Coeficiente de correlación (forma fácil)", df.corr())
                                        #(corr) correlación
from scipy.stats import pearsonr
print ("Coeficiente de correlación= ", pearsonr(x,y)) #calcula el coeficiente de correlación y el valor-p


# inciso 5) Calcule el coeficiente de determinación e interprete el resultado.
r2 = r**2
print ("Coeficiente de determinación: ", r2) #para calcular el coeficiente de determinación
# por lo que el coeficiente de determinación depende de la cantidad
#r = pearsonr (x,y)
print ("Coeficiente de determinación: ", round(r2, 4)) # Alt + teclado de :_ y - = \
                                                      #Alt + teclado de :} y ] = ~ (significa: pertenece a...)

# inciso 6) Obtenga la recta de regresión ajustada y grafíquelo sobre el gráfico de dispersión.
import statsmodels.api as sm
x_constante=sm.add_constant(x) #Tabla de examenes cortos
modelo = sm.OLS(y,x_constante).fit() #Sólo asignamos
modelo.params #queremos ver los modelos de parámetros (da una gráfica) Y:promedio final
print (modelo.params)
#si lo que remos ver con print (print ("parámetros: ", modelo.params))
yc = modelo.predict (x_constante)
plt.plot (x, yc, color = "grey", linestyle = "--",
          linewidth = 2, alpha = 0.5)
#forma difícil(no hacer caso){
from sklearn.metrics import r2_score
r2 = r2_score (y, yc)
#forma difícil}
plt.show()

# inciso 7) Obtenga un intervalo de confianza del 95% para la pendiente de la recta de regresión ajustada ( b1 )
intervalo_de_confianza = modelo.conf_int (alpha = 0.05)
intervalo_de_confianza
print ("intervalos de confianza: ", intervalo_de_confianza)


# inciso 8) Calcule los residuales y trace un nuevo gráfico de dispersión. Comente, ¿Parece que se verifican los supuestos?
import matplotlib.pyplot as plt
residuales = modelo.resid
plt.figure (figsize = (16,8), dpi = 100) # crea una gráfica
plt.scatter(x,residuales, label = "residuales", color = "pink", s = 30)
plt.xlabel("Ausencias", fontsize = 20)  # el label nombra el eje (x)
plt.ylabel("Categoría de Salario", fontsize = 20)   # el label nombra el eje (y)
plt.title("Gráfico de Residuales", fontsize = 20)
plt.gca() .spines [["top","right"]].set_visible (False) # borra la línea de arriba y la derecha
plt.grid()
plt.legend()
plt.axhline(y = 0, color = "gray", linestyle = "--") #crea una línea punteada en el gráfico
plt.show()


# inciso 9) Realice la prueba de Shapiro para los residuales y comente el resultado.
from scipy.stats import shapiro
estadistico_shapiro, valor_p_shapiro = shapiro (residuales) #asigna el valor_p
print("valor_p (shapiro) = ", valor_p_shapiro) #imprime el valor_p de shapiro
#indica la normalidad el dato estadístico aunque en la gráfica no se vea así a simple vista
#por el nivel de significancia, si es mayor a 0.05 hay normalidad, en base a las hipótesis de Word


# inciso 10) Realice la prueba de Brausch-Pagan para los residuales y comente el resultado.
from statsmodels.stats.api import het_breuschpagan
_, valor_p_bp, _, _ = het_breuschpagan(residuales, x_constante)
print(f'valor_p de Breusch-Pagan: {valor_p_bp: 0.4f}\n')
#indica que si hay homocedasticidad por el valor_p


# inciso 11) Utiliza la recta de regresión para interpolar dos valores y extrapolar uno. Comenta estos resultados.
modelo.params
#f(x) = 24.52 + 0.64X
#f(70) = 24.52 + 0.64(70) = 69.32
print("x = 14, ",modelo.predict([1,14]))
print("x = 29, ",modelo.predict([1,29]))
print("x = 77, ",modelo.predict([1,77]))


# inciso 12) Realice una tabla ANOVA e interprete el resultado.
from statsmodels.formula.api import ols
modelo_lineal = ols("categoría_salario ~ ausencias", data = df).fit()
tabla_anova =  sm.stats.anova_lm(modelo_lineal)
tabla_anova
# Out:
# 1269.7142857142858
# -332.42857142857144
# 112.35714285714286
# coeficiente de correlación=  -0.8801
# Coeficiente de correlación (forma fácil)                    ausencias  categoría_salario
# ausencias           1.000000          -0.880126
# categoría_salario  -0.880126           1.000000
# Coeficiente de correlación=  PearsonRResult(statistic=np.float64(-0.8801262960169057), pvalue=np.float64(3.292893088695302e-05))
# Coeficiente de determinación:  0.7746222969404378
# Coeficiente de determinación:  0.7746
# const        14.058843
# ausencias    -0.261814
# dtype: float64
# intervalos de confianza:                     0          1
# const      11.587445  16.530241
# ausencias  -0.350638  -0.172989
# valor_p (shapiro) =  0.4172971767713699
# valor_p de Breusch-Pagan:  0.8955
#
# x = 14,  [10.39345185]
# x = 29,  [6.46624662]
# x = 77,  [-6.10081008]
#              df     sum_sq    mean_sq          F    PR(>F)
# ausencias   1.0  87.034348  87.034348  41.243954  0.000033
# Residual   12.0  25.322795   2.110233        NaN       NaN

# %% [markdown]
# ### Problema 3
# A menudo, quienes hacen la contabilidad de costos estiman los gastos generales con base en el nivel de producción. En Standard Knitting Co. han reunido información acerca de los gastos generales y las unidades producidas en diferentes plantas.
#
# | Gastos generales | 191 | 170 | 272 | 155 | 280 | 173 | 234 | 116 | 153 | 178 |
# |------------------|-----|-----|-----|-----|-----|-----|-----|-----|-----|-----|
# | Unidades        |  40 |  42 |  53 |  35 |  56 |  39 |  48 |  30 |  37 |  40 |
#
# 1.   Establesca una variable dependiente ($Y$) y una variable independiente ($X$).
# 2.   Realice un diagrama de dispersión para estos datos.
# 3. ¿Los datos soportan la suposición de linealidad?
# 4. Calcule el coeficiente de correlación e interprete el resultado.
# 5. Calcule el coeficiente de determinación e interprete el resultado.
# 6. Obtenga la recta de regresión ajustada y grafíquelo sobre el gráfico de dispersión.
# 7. Obtenga un intervalo de confianza del 95% para la pendiente de la recta de regresión ajustada ($b_1$)
# 8. Calcule los residuales y trace un nuevo gráfico de dispersión. Comente, ¿Parece que se verifican los supuestos?
# 9. Realice la prueba de Shapiro para los residuales y comente el resultado.
# 10. Realice la prueba de Brausch-Pagan para los residuales y comente el resultado.
# 11. Utiliza la recta de regresión para interpolar dos valores y extrapolar uno. Comenta estos resultados.
# 12. Realice una tabla ANOVA e interprete el resultado.

# %%
import pandas as pd
df = pd.DataFrame({
"gastos_generales": [191,170,272,155,280,173,234,116,153,178],
"unidades": [40,42,53,35,56,39,48,30,37,40]
})


# inciso 1) Establesca una variable dependiente ( Y ) y una variable independiente ( X ).
# Salario ~ ausencia (y ~ x)
x = df["unidades"]
y = df["gastos_generales"]


# inciso 2) Realice un diagrama de dispersión para estos datos.
import matplotlib.pyplot as plt
plt.figure (figsize = (16,8), dpi = 100) # crea una gráfica
plt.scatter(x,y, label = "Produccion", color = "pink", s = 30)
plt.xlabel("unidades", fontsize = 20)  # el label nombra el eje (x)
plt.ylabel("gastos generales", fontsize = 20)   # el label nombra el eje (y)
plt.title("Gráfico de dispersión", fontsize = 20)
plt.gca() .spines [["top","right"]].set_visible (False) # borra la línea de arriba y la derecha
plt.grid() # genera líneas entre cada número
plt.legend() # para que aparezcan los (label) (llama las etiquetas que usamos)
 # se cierra el gráfico con plt.show()



# inciso 3) ¿Los datos soportan la suposición de linealidad?
            # Sí soporta la suposición de linealidad por el momento en r


# inciso 4) Calcule el coeficiente de correlación e interprete el resultado.
                                        #forma difícil {
Sxx = sum((x - x.mean())**2)
Sxy = sum((x - x.mean())*(y - y.mean()))
Syy = sum((y - y.mean())**2)

print (Sxx)
print (Sxy)
print (Syy)

from math import sqrt
r = Sxy / sqrt (Sxx * Syy)
print ("coeficiente de correlación= ", round (r,4) )
                                        #forma difícil }
print ("Coeficiente de correlación (forma fácil)", df.corr())
                                        #(corr) correlación
from scipy.stats import pearsonr
print ("Coeficiente de correlación= ", pearsonr(x,y)) #calcula el coeficiente de correlación y el valor-p


# inciso 5) Calcule el coeficiente de determinación e interprete el resultado.
r2 = r**2
print ("Coeficiente de determinación: ", r2) #para calcular el coeficiente de determinación
# por lo que el coeficiente de determinación depende de la cantidad
#r = pearsonr (x,y)
print ("Coeficiente de determinación: ", round(r2, 4)) # Alt + teclado de :_ y - = \
                                                      #Alt + teclado de :} y ] = ~ (significa: pertenece a...)

# inciso 6) Obtenga la recta de regresión ajustada y grafíquelo sobre el gráfico de dispersión.
import statsmodels.api as sm
x_constante=sm.add_constant(x) #Tabla de examenes cortos
modelo = sm.OLS(y,x_constante).fit() #Sólo asignamos
modelo.params #queremos ver los modelos de parámetros (da una gráfica) Y:promedio final
print (modelo.params)
#si lo que remos ver con print (print ("parámetros: ", modelo.params))
yc = modelo.predict (x_constante)
plt.plot (x, yc, color = "grey", linestyle = "--",
          linewidth = 2, alpha = 0.5)
#forma difícil(no hacer caso){
from sklearn.metrics import r2_score
r2 = r2_score (y, yc)
#forma difícil}
plt.show()

# inciso 7) Obtenga un intervalo de confianza del 95% para la pendiente de la recta de regresión ajustada ( b1 )
intervalo_de_confianza = modelo.conf_int (alpha = 0.05)
intervalo_de_confianza
print ("intervalos de confianza: ", intervalo_de_confianza)


# inciso 8) Calcule los residuales y trace un nuevo gráfico de dispersión. Comente, ¿Parece que se verifican los supuestos?
import matplotlib.pyplot as plt
residuales = modelo.resid
plt.figure (figsize = (16,8), dpi = 100) # crea una gráfica
plt.scatter(x,residuales, label = "residuales", color = "pink", s = 30)
plt.xlabel("unidades", fontsize = 20)  # el label nombra el eje (x)
plt.ylabel("Gastos generales", fontsize = 20)   # el label nombra el eje (y)
plt.title("Gráfico de Residuales", fontsize = 20)
plt.gca() .spines [["top","right"]].set_visible (False) # borra la línea de arriba y la derecha
plt.grid()
plt.legend()
plt.axhline(y = 0, color = "gray", linestyle = "--") #crea una línea punteada en el gráfico
plt.show()


# inciso 9) Realice la prueba de Shapiro para los residuales y comente el resultado.
from scipy.stats import shapiro
estadistico_shapiro, valor_p_shapiro = shapiro (residuales) #asigna el valor_p
print("valor_p (shapiro) = ", valor_p_shapiro) #imprime el valor_p de shapiro
#indica la normalidad el dato estadístico aunque en la gráfica no se vea así a simple vista
#por el nivel de significancia, si es mayor a 0.05 hay normalidad, en base a las hipótesis de Word


# inciso 10) Realice la prueba de Brausch-Pagan para los residuales y comente el resultado.
from statsmodels.stats.api import het_breuschpagan
_, valor_p_bp, _, _ = het_breuschpagan(residuales, x_constante)
print(f'valor_p de Breusch-Pagan: {valor_p_bp: 0.4f}\n')
#indica que si hay homocedasticidad por el valor_p


# inciso 11) Utiliza la recta de regresión para interpolar dos valores y extrapolar uno. Comenta estos resultados.
modelo.params
#f(x) = 24.52 + 0.64X
#f(70) = 24.52 + 0.64(70) = 69.32
print("x = 40, ",modelo.predict([1,40]))
print("x = 50, ",modelo.predict([1,50]))
print("x = 100, ",modelo.predict([1,100]))


# inciso 12) Realice una tabla ANOVA e interprete el resultado.
from statsmodels.formula.api import ols
modelo_lineal = ols("gastos_generales ~ unidades", data = df).fit()
tabla_anova =  sm.stats.anova_lm(modelo_lineal)
tabla_anova
# Out:
# 588.0
# 3817.0
# 25615.600000000002
# coeficiente de correlación=  0.9835
# Coeficiente de correlación (forma fácil)                   gastos_generales  unidades
# gastos_generales          1.000000  0.983516
# unidades                  0.983516  1.000000
# Coeficiente de correlación=  PearsonRResult(statistic=np.float64(0.9835155492696092), pvalue=np.float64(3.1670797383293894e-07))
# Coeficiente de determinación:  0.967302835655101
# Coeficiente de determinación:  0.9673
# const      -80.442857
# unidades     6.491497
# dtype: float64
# intervalos de confianza:                     0          1
# const    -121.986373 -38.899341
# unidades    5.518450   7.464543
# valor_p (shapiro) =  0.22045077017698533
# valor_p de Breusch-Pagan:  0.9858
#
# x = 40,  [179.2170068]
# x = 50,  [244.13197279]
# x = 100,  [568.70680272]
#            df        sum_sq       mean_sq           F        PR(>F)
# unidades  1.0  24778.042517  24778.042517  236.669535  3.167080e-07
# Residual  8.0    837.557483    104.694685         NaN           NaN

# %% [markdown]
# ### Problema 4
# Las ventas de línea blanca varían según el estado del mercado de casas nuevas: cuando las ventas de casas nuevas son buenas, también lo son las de lavaplatos, lavadoras de ropa, secadoras y refrigeradores.
# Una asociación de comercio compiló los siguientes datos históricos (en miles de unidades) de las ventas de línea blanca y la construcción de casas.
#
# | Construcción de casas (miles) | Ventas de línea blanca (miles) |
# |-------------------------------|--------------------------------|
# | 2.0                           | 5.0                            |
# | 2.5                           | 5.5                            |
# | 3.2                           | 6.0                            |
# | 3.6                           | 7.0                            |
# | 3.7                           | 7.2                            |
# | 4.0                           | 7.7                            |
# | 4.2                           | 8.4                            |
# | 4.6                           | 9.0                            |
# | 4.8                           | 9.7                            |
# | 5.0                           | 10.0                           |
#
# 1.   Establesca una variable dependiente ($Y$) y una variable independiente ($X$).
# 2.   Realice un diagrama de dispersión para estos datos.
# 3. ¿Los datos soportan la suposición de linealidad?
# 4. Calcule el coeficiente de correlación e interprete el resultado.
# 5. Calcule el coeficiente de determinación e interprete el resultado.
# 6. Obtenga la recta de regresión ajustada y grafíquelo sobre el gráfico de dispersión.
# 7. Obtenga un intervalo de confianza del 95% para la pendiente de la recta de regresión ajustada ($b_1$)
# 8. Calcule los residuales y trace un nuevo gráfico de dispersión. Comente, ¿Parece que se verifican los supuestos?
# 9. Realice la prueba de Shapiro para los residuales y comente el resultado.
# 10. Realice la prueba de Brausch-Pagan para los residuales y comente el resultado.
# 11. Utiliza la recta de regresión para interpolar dos valores y extrapolar uno. Comenta estos resultados.
# 12. Realice una tabla ANOVA e interprete el resultado.

# %%
import pandas as pd
df = pd.DataFrame({
"construcción_casas": [18,17,29,36,11,28,35,14,20,32,39,16,31,40],
"venta_línea_blanca": [11,10,8,5,9,7,3,11,8,7,2,9,8,3]
})


# inciso 1) Establesca una variable dependiente ( Y ) y una variable independiente ( X ).
# Salario ~ ausencia (y ~ x)
x = df["construcción_casas"]
y = df["venta_línea_blanca"]


# inciso 2) Realice un diagrama de dispersión para estos datos.
import matplotlib.pyplot as plt
plt.figure (figsize = (16,8), dpi = 100) # crea una gráfica
plt.scatter(x,y, label = "Mercado", color = "pink", s = 30)
plt.xlabel("Construcción de Casas", fontsize = 20)  # el label nombra el eje (x)
plt.ylabel("Venta de línea blanca", fontsize = 20)   # el label nombra el eje (y)
plt.title("Gráfico de dispersión", fontsize = 20)
plt.gca() .spines [["top","right"]].set_visible (False) # borra la línea de arriba y la derecha
plt.grid() # genera líneas entre cada número
plt.legend() # para que aparezcan los (label) (llama las etiquetas que usamos)
 # se cierra el gráfico con plt.show()



# inciso 3) ¿Los datos soportan la suposición de linealidad?
            # Sí soporta la suposición de linealidad por el momento en r


# inciso 4) Calcule el coeficiente de correlación e interprete el resultado.
                                        #forma difícil {
Sxx = sum((x - x.mean())**2)
Sxy = sum((x - x.mean())*(y - y.mean()))
Syy = sum((y - y.mean())**2)

print (Sxx)
print (Sxy)
print (Syy)

from math import sqrt
r = Sxy / sqrt (Sxx * Syy)
print ("coeficiente de correlación= ", round (r,4) )
                                        #forma difícil }
print ("Coeficiente de correlación (forma fácil)", df.corr())
                                        #(corr) correlación
from scipy.stats import pearsonr
print ("Coeficiente de correlación= ", pearsonr(x,y)) #calcula el coeficiente de correlación y el valor-p


# inciso 5) Calcule el coeficiente de determinación e interprete el resultado.
r2 = r**2
print ("Coeficiente de determinación: ", r2) #para calcular el coeficiente de determinación
# por lo que el coeficiente de determinación depende de la cantidad
#r = pearsonr (x,y)
print ("Coeficiente de determinación: ", round(r2, 4)) # Alt + teclado de :_ y - = \
                                                      #Alt + teclado de :} y ] = ~ (significa: pertenece a...)

# inciso 6) Obtenga la recta de regresión ajustada y grafíquelo sobre el gráfico de dispersión.
import statsmodels.api as sm
x_constante=sm.add_constant(x) #Tabla de examenes cortos
modelo = sm.OLS(y,x_constante).fit() #Sólo asignamos
modelo.params #queremos ver los modelos de parámetros (da una gráfica) Y:promedio final
print (modelo.params)
#si lo que remos ver con print (print ("parámetros: ", modelo.params))
yc = modelo.predict (x_constante)
plt.plot (x, yc, color = "grey", linestyle = "--",
          linewidth = 2, alpha = 0.5)
#forma difícil(no hacer caso){
from sklearn.metrics import r2_score
r2 = r2_score (y, yc)
#forma difícil}
plt.show()

# inciso 7) Obtenga un intervalo de confianza del 95% para la pendiente de la recta de regresión ajustada ( b1 )
intervalo_de_confianza = modelo.conf_int (alpha = 0.05)
intervalo_de_confianza
print ("intervalos de confianza: ", intervalo_de_confianza)


# inciso 8) Calcule los residuales y trace un nuevo gráfico de dispersión. Comente, ¿Parece que se verifican los supuestos?
import matplotlib.pyplot as plt
residuales = modelo.resid
plt.figure (figsize = (16,8), dpi = 100) # crea una gráfica
plt.scatter(x,residuales, label = "residuales", color = "pink", s = 30)
plt.xlabel("Construcción de Casas", fontsize = 20)  # el label nombra el eje (x)
plt.ylabel("Venta de línea blanca", fontsize = 20)   # el label nombra el eje (y)
plt.title("Gráfico de Residuales", fontsize = 20)
plt.gca() .spines [["top","right"]].set_visible (False) # borra la línea de arriba y la derecha
plt.grid()
plt.legend()
plt.axhline(y = 0, color = "gray", linestyle = "--") #crea una línea punteada en el gráfico
plt.show()


# inciso 9) Realice la prueba de Shapiro para los residuales y comente el resultado.
from scipy.stats import shapiro
estadistico_shapiro, valor_p_shapiro = shapiro (residuales) #asigna el valor_p
print("valor_p (shapiro) = ", valor_p_shapiro) #imprime el valor_p de shapiro
#indica la normalidad el dato estadístico aunque en la gráfica no se vea así a simple vista
#por el nivel de significancia, si es mayor a 0.05 hay normalidad, en base a las hipótesis de Word


# inciso 10) Realice la prueba de Brausch-Pagan para los residuales y comente el resultado.
from statsmodels.stats.api import het_breuschpagan
_, valor_p_bp, _, _ = het_breuschpagan(residuales, x_constante)
print(f'valor_p de Breusch-Pagan: {valor_p_bp: 0.4f}\n')
#indica que si hay homocedasticidad por el valor_p


# inciso 11) Utiliza la recta de regresión para interpolar dos valores y extrapolar uno. Comenta estos resultados.
modelo.params
#f(x) = 24.52 + 0.64X
#f(70) = 24.52 + 0.64(70) = 69.32
print("x = 4.7, ",modelo.predict([1,4.7]))
print("x = 3, ",modelo.predict([1,3]))
print("x = 10, ",modelo.predict([1,10]))


# inciso 12) Realice una tabla ANOVA e interprete el resultado.
from statsmodels.formula.api import ols
modelo_lineal = ols("construcción_casas ~ venta_línea_blanca", data = df).fit()
tabla_anova =  sm.stats.anova_lm(modelo_lineal)
tabla_anova
# Out:
# 1269.7142857142858
# -332.42857142857144
# 112.35714285714286
# coeficiente de correlación=  -0.8801
# Coeficiente de correlación (forma fácil)                     construcción_casas  venta_línea_blanca
# construcción_casas            1.000000           -0.880126
# venta_línea_blanca           -0.880126            1.000000
# Coeficiente de correlación=  PearsonRResult(statistic=np.float64(-0.8801262960169057), pvalue=np.float64(3.292893088695302e-05))
# Coeficiente de determinación:  0.7746222969404378
# Coeficiente de determinación:  0.7746
# const                 14.058843
# construcción_casas    -0.261814
# dtype: float64
# intervalos de confianza:                              0          1
# const               11.587445  16.530241
# construcción_casas  -0.350638  -0.172989
# valor_p (shapiro) =  0.4172971767713699
# valor_p de Breusch-Pagan:  0.8955
#
# x = 4.7,  [12.82831908]
# x = 3,  [13.27340234]
# x = 10,  [11.44070657]
#                       df      sum_sq     mean_sq          F    PR(>F)
# venta_línea_blanca   1.0  983.548996  983.548996  41.243954  0.000033
# Residual            12.0  286.165289   23.847107        NaN       NaN

# %% [markdown]
# ### Problema 5
# William C. Andrews, consultor de comportamiento organizacional de Victory Motorcycles, ha diseñado una prueba para mostrar a los supervisores de la compañía los peligros de sobrevigilar a sus trabajadores.
# Un trabajador de la línea de ensamble tiene a su cargo una serie de tareas complicadas. Durante el desempeño del trabajador, un inspector lo interrumpe constantemente para ayudarlo a terminar las tareas.
# El trabajador, después de terminar su trabajo, recibe una prueba psicológica diseñada para medir la hostilidad del trabajador hacia la autoridad
# (una alta puntuación implica una hostilidad baja). A ocho distintos trabajadores se les asignaron las tareas y luego se les interrumpió para darles instrucciones útiles un número variable de veces (línea X).
# Sus calificaciones en la prueba de hostilidad se dan en el renglón Y.
#
# | número interrupciones al trabajador |  5  | 10  | 10  | 15  | 15  | 20  | 20  | 25  |
# |-----------------------------------------|----|----|----|----|----|----|----|----|
# | calificación del trabajador en la prueba de hostilidad | 58  | 41  | 45  | 27  | 26  | 12  | 16  |  3  |
#
# 1.   Establesca una variable dependiente ($Y$) y una variable independiente ($X$).
# 2.   Realice un diagrama de dispersión para estos datos.
# 3. ¿Los datos soportan la suposición de linealidad?
# 4. Calcule el coeficiente de correlación e interprete el resultado.
# 5. Calcule el coeficiente de determinación e interprete el resultado.
# 6. Obtenga la recta de regresión ajustada y grafíquelo sobre el gráfico de dispersión.
# 7. Obtenga un intervalo de confianza del 95% para la pendiente de la recta de regresión ajustada ($b_1$)
# 8. Calcule los residuales y trace un nuevo gráfico de dispersión. Comente, ¿Parece que se verifican los supuestos?
# 9. Realice la prueba de Shapiro para los residuales y comente el resultado.
# 10. Realice la prueba de Brausch-Pagan para los residuales y comente el resultado.
# 11. Utiliza la recta de regresión para interpolar dos valores y extrapolar uno. Comenta estos resultados.
# 12. Realice una tabla ANOVA e interprete el resultado.

# %%
import pandas as pd
df = pd.DataFrame({
"num_interrupciones_trabajador": [18,17,29,36,11,28,35,14,20,32,39,16,31,40],
"calf_trabajador_prueba_hostilidad": [11,10,8,5,9,7,3,11,8,7,2,9,8,3]
})


# inciso 1) Establesca una variable dependiente ( Y ) y una variable independiente ( X ).
# Salario ~ ausencia (y ~ x)
x = df["num_interrupciones_trabajador"]
y = df["calf_trabajador_prueba_hostilidad"]


# inciso 2) Realice un diagrama de dispersión para estos datos.
import matplotlib.pyplot as plt
plt.figure (figsize = (16,8), dpi = 100) # crea una gráfica
plt.scatter(x,y, label = "Peligros de sobrevigilar a los trabajadores", color = "pink", s = 30)
plt.xlabel("Numero de interrupciones al trabajador", fontsize = 20)  # el label nombra el eje (x)
plt.ylabel("Calificación del trabajador en la prueba de hostilidad", fontsize = 20)   # el label nombra el eje (y)
plt.title("Gráfico de dispersión", fontsize = 20)
plt.gca() .spines [["top","right"]].set_visible (False) # borra la línea de arriba y la derecha
plt.grid() # genera líneas entre cada número
plt.legend() # para que aparezcan los (label) (llama las etiquetas que usamos)
 # se cierra el gráfico con plt.show()



# inciso 3) ¿Los datos soportan la suposición de linealidad?
            # Sí soporta la suposición de linealidad por el momento en r


# inciso 4) Calcule el coeficiente de correlación e interprete el resultado.
                                        #forma difícil {
Sxx = sum((x - x.mean())**2)
Sxy = sum((x - x.mean())*(y - y.mean()))
Syy = sum((y - y.mean())**2)

print (Sxx)
print (Sxy)
print (Syy)

from math import sqrt
r = Sxy / sqrt (Sxx * Syy)
print ("coeficiente de correlación= ", round (r,4) )
                                        #forma difícil }
print ("Coeficiente de correlación (forma fácil)", df.corr())
                                        #(corr) correlación
from scipy.stats import pearsonr
print ("Coeficiente de correlación= ", pearsonr(x,y)) #calcula el coeficiente de correlación y el valor-p


# inciso 5) Calcule el coeficiente de determinación e interprete el resultado.
r2 = r**2
print ("Coeficiente de determinación: ", r2) #para calcular el coeficiente de determinación
# por lo que el coeficiente de determinación depende de la cantidad
#r = pearsonr (x,y)
print ("Coeficiente de determinación: ", round(r2, 4)) # Alt + teclado de :_ y - = \
                                                      #Alt + teclado de :} y ] = ~ (significa: pertenece a...)

# inciso 6) Obtenga la recta de regresión ajustada y grafíquelo sobre el gráfico de dispersión.
import statsmodels.api as sm
x_constante=sm.add_constant(x) #Tabla de examenes cortos
modelo = sm.OLS(y,x_constante).fit() #Sólo asignamos
modelo.params #queremos ver los modelos de parámetros (da una gráfica) Y:promedio final
print (modelo.params)
#si lo que remos ver con print (print ("parámetros: ", modelo.params))
yc = modelo.predict (x_constante)
plt.plot (x, yc, color = "grey", linestyle = "--",
          linewidth = 2, alpha = 0.5)
#forma difícil(no hacer caso){
from sklearn.metrics import r2_score
r2 = r2_score (y, yc)
#forma difícil}
plt.show()

# inciso 7) Obtenga un intervalo de confianza del 95% para la pendiente de la recta de regresión ajustada ( b1 )
intervalo_de_confianza = modelo.conf_int (alpha = 0.05)
intervalo_de_confianza
print ("intervalos de confianza: ", intervalo_de_confianza)


# inciso 8) Calcule los residuales y trace un nuevo gráfico de dispersión. Comente, ¿Parece que se verifican los supuestos?
import matplotlib.pyplot as plt
residuales = modelo.resid
plt.figure (figsize = (16,8), dpi = 100) # crea una gráfica
plt.scatter(x,residuales, label = "residuales", color = "pink", s = 30) #dispersión
plt.xlabel("Numero de interrupciones al trabajador", fontsize = 20)  # el label nombra el eje (x)
plt.ylabel("Calificación del trabajador en la prueba de hostilidad", fontsize = 20)   # el label nombra el eje (y)
plt.title("Gráfico de Residuales", fontsize = 20)
plt.gca() .spines [["top","right"]].set_visible (False) # borra la línea de arriba y la derecha
plt.grid() #cuadrícula
plt.legend() #muestra la leyenda de la tabla (residuales)
plt.axhline(y = 0, color = "gray", linestyle = "--") #crea una línea punteada en el gráfico
plt.show()


# inciso 9) Realice la prueba de Shapiro para los residuales y comente el resultado.
from scipy.stats import shapiro
estadistico_shapiro, valor_p_shapiro = shapiro (residuales) #asigna el valor_p
print("valor_p (shapiro) = ", valor_p_shapiro) #imprime el valor_p de shapiro
#indica la normalidad el dato estadístico aunque en la gráfica no se vea así a simple vista
#por el nivel de significancia, si es mayor a 0.05 hay normalidad, en base a las hipótesis de Word


# inciso 10) Realice la prueba de Brausch-Pagan para los residuales y comente el resultado.
from statsmodels.stats.api import het_breuschpagan
_, valor_p_bp, _, _ = het_breuschpagan(residuales, x_constante)
print(f'valor_p de Breusch-Pagan: {valor_p_bp: 0.4f}\n')
#indica que si hay homocedasticidad por el valor_p


# inciso 11) Utiliza la recta de regresión para interpolar dos valores y extrapolar uno. Comenta estos resultados.
modelo.params
#f(x) = 24.52 + 0.64X
#f(70) = 24.52 + 0.64(70) = 69.32
print("x = 14, ",modelo.predict([1,14]))
print("x = 29, ",modelo.predict([1,29]))
print("x = 77, ",modelo.predict([1,77]))


# inciso 12) Realice una tabla ANOVA e interprete el resultado.
from statsmodels.formula.api import ols
modelo_lineal = ols("calf_trabajador_prueba_hostilidad ~ num_interrupciones_trabajador", data = df).fit()
tabla_anova =  sm.stats.anova_lm(modelo_lineal)
tabla_anova
# Out:
# 1269.7142857142858
# -332.42857142857144
# 112.35714285714286
# coeficiente de correlación=  -0.8801
# Coeficiente de correlación (forma fácil)                                    num_interrupciones_trabajador  \
# num_interrupciones_trabajador                           1.000000
# calf_trabajador_prueba_hostilidad                      -0.880126
#
#                                    calf_trabajador_prueba_hostilidad
# num_interrupciones_trabajador                              -0.880126
# calf_trabajador_prueba_hostilidad                           1.000000
# Coeficiente de correlación=  PearsonRResult(statistic=np.float64(-0.8801262960169057), pvalue=np.float64(3.292893088695302e-05))
# Coeficiente de determinación:  0.7746222969404378
# Coeficiente de determinación:  0.7746
# const                            14.058843
# num_interrupciones_trabajador    -0.261814
# dtype: float64
# intervalos de confianza:                                         0          1
# const                          11.587445  16.530241
# num_interrupciones_trabajador  -0.350638  -0.172989
# valor_p (shapiro) =  0.4172971767713699
# valor_p de Breusch-Pagan:  0.8955
#
# x = 14,  [10.39345185]
# x = 29,  [6.46624662]
# x = 77,  [-6.10081008]
#                                  df     sum_sq    mean_sq          F    PR(>F)
# num_interrupciones_trabajador   1.0  87.034348  87.034348  41.243954  0.000033
# Residual                       12.0  25.322795   2.110233        NaN       NaN
